# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanawadhwa/First-Day-in-Python/blob/main/dtapp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# USER PROFILE

# %%
profile = {
   "name" : "Ashish",
   "age" : 21,
   "interest" : "music",
   "city" : "pune"

}

profile["name"]
# Out:
# 'Ashish'

# %% [markdown]
# DATING APP

# %%
def create_profile(name,age,interest,city):
  profile = {
   "name" : name,
   "age" : age,
   "interest" : interest,
   "city" : city
  }
  return profile

# %%
create_profile("Ashika",24,"music","pune")
# Out:
# {'name': 'Ashika', 'age': 21, 'interest': 'music', 'city': 'pune'}

# %%
def calculate_match_score(profile1,profile2):
  score = 0

  #same interest
  if profile1["interest"] == profile2["interest"]:
    score = score + 50

  #same city
  if profile1["city"] == profile2["city"]:
    score = score + 30

  #age difference
  #we use abs because we need the absolute i.e. positive value
  age_diff = abs(profile1["age"] - profile2["age"])
  if age_diff <= 2:
    score = score+20


  return score

# %%
def is_match(score):
  if score >= 60:
    return True
  else :
    return False

# %%
is_match(23)
# Out:
# False

# %%
is_match(90)
# Out:
# True

# %%
def display_results(profile1,profile2,score):
  print("Welcome to the dating app")
  print("="*40)
  print("Person 1",profile1["name"])
  print("Person 2",profile2["name"])
  print("Compatibility score", score)

  if is_match(score):
    print("its a match")
  else:
    print("you are still single, keep moving")

# %% [markdown]
# RUN THE PROGRAM

# %%
user1 = create_profile("ashish",21,"music","delhi")
user2 = create_profile("ashika",19,"trekking","pune")

match_score = calculate_match_score(user1,user2)

display_results(user1 , user2 , match_score)
# Out:
# Welcome to the dating app
# ...
# Person 1 ashish
# Person 2 ashika
# Compatibility score 20
# you are still single, keep moving
