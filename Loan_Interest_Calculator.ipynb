# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanawadhwa/First-Day-in-Python/blob/main/Loan_Interest_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loan Interest Calculator

print("LOAN INTEREST CALCULATOR")
print("------------------------")


principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate of interest (in %): "))
time = float(input("Enter time period (in years): "))


interest = (principal * rate * time) / 100


total_amount = principal + interest


print("\nInterest to be paid =", interest)
print("Total repayment amount =", total_amount)
# Out:
# LOAN INTEREST CALCULATOR
# ------------------------
# Enter principal amount: 200
# Enter rate of interest (in %): 10
# Enter time period (in years): 3
#
# Interest to be paid = 60.0
# Total repayment amount = 260.0
