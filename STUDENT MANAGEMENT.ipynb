# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanawadhwa/First-Day-in-Python/blob/main/STUDENT%20MANAGEMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
meow= "cat"

# %%
print(meow)
# Out:
# cat

# %%
meow2 = "cat says"

# %%
print(meow2)
# Out:
# cat says meow

# %%
meow3 = "cat says meow"

# %%
print(meow3)
# Out:
# cat says meow

# %%
meow4 = "cat says meow meow"

# %%
print(meow4)
# Out:
# cat says meow meow

# %%
meow5 = "cat says meow meow meow"

# %%
print(meow5)
# Out:
# cat says meow meow meow

# %%
def calculate_total(marks):
    total = sum(marks)
    return total

# %%
def calculate_percentage(total):
    percentage = total / 5
    return percentage

# %%
def calculate_grade(percentage):
    if percentage >= 75:
        return "A"
    elif percentage >= 60:
        return "B"
    elif percentage >= 50:
        return "C"
    elif percentage >= 40:
        return "D"
    else:
        return "Fail"

# %%
# Dictionary to store student records
students = {}

while True:
    print("\n--- Student Result Management System ---")
    print("1. Add Student Result")
    print("2. Display All Results")
    print("3. Exit")

    choice = input("Enter your choice (1/2/3): ")

    if choice == "1":
        name = input("Enter student name: ")

        marks = []
        for i in range(1, 6):
            mark = float(input(f"Enter marks for Subject {i}: "))
            marks.append(mark)

        total = calculate_total(marks)
        percentage = calculate_percentage(total)
        grade = calculate_grade(percentage)

        # Store student data in dictionary
        students[name] = {
            "Marks": marks,
            "Total": total,
            "Percentage": percentage,
            "Grade": grade
        }

        print("\nStudent result added successfully!")

    elif choice == "2":
        if not students:
            print("\nNo student records available.")
        else:
            print("\n--- Student Result Summary ---")
            for name, details in students.items():
                print("\nStudent Name:", name)
                print("Marks:", details["Marks"])
                print("Total Marks:", details["Total"])
                print("Percentage:", details["Percentage"])
                print("Grade:", details["Grade"])

    elif choice == "3":
        print("\nThank you for using the system.")
        break
    else:
        print("\nInvalid choice. Please try again.")
# Out:
# --- Student Result Management System ---
# 1. Add Student Result
# 2. Display All Results
# 3. Exit
# Enter your choice (1/2/3): 1
# Enter student name: A
# Enter marks for Subject 1: 200000000000000000000000
# Enter marks for Subject 2: 666666666666
# Enter marks for Subject 3: 87777777777777777777777
# Enter marks for Subject 4: 666666666666666666666
