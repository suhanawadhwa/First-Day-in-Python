# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanawadhwa/First-Day-in-Python/blob/main/Savings_Growth_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Savings Growth Calculator

print("SAVINGS GROWTH CALCULATOR")
print("-------------------------")

monthly_savings = float(input("Enter monthly savings amount: "))
months = int(input("Enter number of months: "))


total_savings = monthly_savings * months

print("\nTotal Savings after", months, "months =", total_savings)
# Out:
# SAVINGS GROWTH CALCULATOR
# -------------------------
# Enter monthly savings amount: 23333
# Enter number of months: 2343
#
# Total Savings after 2343 months = 54669219.0
